# %%
import numpy as np
import pandas as pd

# %%
import seaborn as sns

# %%
import matplotlib.pyplot as plt
plt.style.use('bmh') #ggplot, bmh, dark_background, fivethirtyeight

# %%
# %matplotlib inline

# %%
df1 = pd.read_csv('df1', index_col=0)

# %%
df2 = pd.read_csv('df2')

# %%
df1['A'].hist()

# %%
df2.plot.area(alpha=.4)

# %%
df2.plot.bar(figsize=(10, 6), stacked=True)

# %%
df1['A'].plot.hist(figsize=(10, 6), bins=50)

# %%
df1.plot.line(x=df1.index, y='B', figsize=(12, 5), lw=1)

# %%
df1.plot.scatter(x='A', y='B', figsize=(10, 6))

# %%
df1.plot.scatter(x='A', y='B', figsize=(10, 6), c='C', cmap='inferno')

# %%
df1.plot.scatter(x='A', y='B', figsize=(10, 6), s=df1['C']*20)
# Out:
# C:\Users\Igo\Anaconda3\lib\site-packages\matplotlib\collections.py:853: RuntimeWarning: invalid value encountered in sqrt
#   scale = np.sqrt(self._sizes) * dpi / 72.0 * self._factor

# %%
df2.plot.box(figsize=(10, 6))

# %%
df = pd.DataFrame(np.random.rand(1000, 2), columns=['A', 'B'])

# %%
df.plot.hexbin(x='A', y='B', figsize=(10, 6), gridsize=20, cmap='Oranges')

# %%
df2['a'].plot.kde(figsize=(10, 5))

# %%
df2.plot.kde(figsize=(10, 5))
