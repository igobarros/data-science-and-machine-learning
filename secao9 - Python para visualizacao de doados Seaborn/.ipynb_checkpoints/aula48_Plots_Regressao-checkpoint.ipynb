# %%
import seaborn as sns
# %matplotlib inline

# %%
tips = sns.load_dataset('tips')

# %%
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
pf = tips.pivot_table(values='size', index='total_bill', columns='tip')
pf
# Out:
# tip         1.00   1.01   1.10   1.17   1.25   1.32   1.36   1.44   1.45   \
# total_bill
# 3.07          1.0    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 5.75          2.0    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 7.25          1.0    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 7.51          NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 7.56          NaN    NaN    NaN    NaN    NaN    NaN    NaN    2.0    NaN
# 7.74          NaN    NaN    NaN    NaN    NaN    NaN    NaN    2.0    NaN
# 8.35          NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 8.51          NaN    NaN    NaN    NaN    2.0    NaN    NaN    NaN    NaN
# 8.52          NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 8.58          NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 8.77          NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# ...
